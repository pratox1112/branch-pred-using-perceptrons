# %%
import torch
import torch.nn as nn
from collections import deque, defaultdict
import os
import time
import matplotlib.pyplot as plt

# %%
class PerceptronPyTorch(nn.Module):
    """
    Implements a perceptron for branch prediction using PyTorch.
    Attributes:
        N: Length of the branch history register.
    Methods:
        predict(branch_history): Predicts the branch outcome.
        update_weights(prediction, actual, branch_history, running_sum): Updates perceptron weights.
    """
    def __init__(self, N):
        super(PerceptronPyTorch, self).__init__()
        self.N = N
        self.linear = nn.Linear(N, 1, bias=True)
        nn.init.zeros_(self.linear.weight)
        nn.init.zeros_(self.linear.bias)
        self.threshold = 2 * N + 14

    def predict(self, branch_history):
        """
        Predicts the outcome of a branch based on the branch history.
        Parameters:
            branch_history (deque): A deque representing recent branch outcomes.
        Returns:
            prediction (int): Predicted branch outcome (-1 for not taken, 1 for taken).
            running_sum (float): The perceptron output value (confidence score).
        """
        input_tensor = torch.tensor(list(branch_history), dtype=torch.float32).unsqueeze(0)
        running_sum = self.linear(input_tensor).item()
        prediction = -1 if running_sum < 0 else 1
        return prediction, running_sum

    def update_weights(self, prediction, actual, branch_history, running_sum):
        """
        Updates perceptron weights if the prediction is incorrect or confidence is low.
        Parameters:
            prediction (int): Predicted branch outcome (-1 or 1).
            actual (int): Actual branch outcome (-1 or 1).
            branch_history (deque): Recent branch outcomes used as input.
            running_sum (float): The perceptron output value.
        """
        if (prediction != actual) or (abs(running_sum) < self.threshold):
            input_tensor = torch.tensor(list(branch_history), dtype=torch.float32).unsqueeze(0)
            actual_tensor = torch.tensor([actual], dtype=torch.float32)
            with torch.no_grad():
                self.linear.weight += actual_tensor * input_tensor
                self.linear.bias += actual_tensor

# %%
def read_trace_from_file(file_path):
    """
    Reads a branch trace file and parses branch addresses and outcomes.
    Parameters:
        file_path (str): Path to the branch trace file.
    Returns:
        trace (list): A list of [branch_address, outcome] pairs.
    """
    trace = []
    try:
        with open(file_path, 'r') as file:
            for line_number, line in enumerate(file, start=1):
                line = line.strip()
                if not line:
                    continue
                parts = line.split()
                if len(parts) != 2:
                    print(f"Warning: Line {line_number} is malformed: '{line}'")
                    continue
                branch_address, outcome_str = parts
                try:
                    outcome = int(outcome_str)
                    if outcome not in (0, 1):
                        print(f"Warning: Line {line_number} has invalid outcome '{outcome}': '{line}'")
                        continue
                except ValueError:
                    print(f"Warning: Line {line_number} has non-integer outcome '{outcome_str}': '{line}'")
                    continue
                trace.append([branch_address, outcome])
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except IOError as e:
        print(f"IOError while reading file '{file_path}': {e}")
    return trace

# %%
def perceptron_pred_pytorch(trace, l=1, tablesize=None):
    """
    Simulates branch prediction using perceptrons.
    Parameters:
        trace (list): List of [branch_address, outcome] pairs from the trace file.
        l (int): Length of the branch history register.
        tablesize (int, optional): Maximum size of the perceptron table. Defaults to None (unlimited size).
    Returns:
        num_correct (int): Number of correct predictions.
        len(p_list) (int): Number of perceptron instances created.
    """
    branch_histories = defaultdict(lambda: deque([0] * l, maxlen=l))
    p_list = {}
    num_correct = 0

    for br in trace:
        branch_address = br[0]
        outcome = 1 if br[1] else -1

        if tablesize:
            index = hash(branch_address) % tablesize
            key = index
        else:
            key = branch_address

        if key not in p_list:
            p_list[key] = PerceptronPyTorch(l)

        local_history = branch_histories[branch_address]
        prediction, running_sum = p_list[key].predict(local_history)
        p_list[key].update_weights(prediction, outcome, local_history, running_sum)
        local_history.appendleft(outcome)

        if prediction == outcome:
            num_correct += 1

    return num_correct, len(p_list)

# %%
def process_trace(file_path, max_l):
    """
    Process a single trace file, run the perceptron predictor for different l values,
    and return the results as lists.
    """
    trace = read_trace_from_file(file_path)
    print(f"Processing {file_path}")
    print(f"Total branches in trace: {len(trace)}\n")

    if len(trace) == 0:
        print("No valid branch data found. Skipping this dataset.")
        return None, None

    accuracies = []
    times = []

    for i in range(1, max_l + 1):
        start_time = time.time()
        num_correct, num_p = perceptron_pred_pytorch(trace, l=i, tablesize=None)
        end_time = time.time()
        duration = end_time - start_time
        accuracy = (num_correct / len(trace)) * 100 if len(trace) > 0 else 0

        accuracies.append(accuracy)
        times.append(duration)

        print(f"i:{i} --> (Accuracy: {accuracy:.2f}%, Time: {duration:.4f} seconds)")

    return accuracies, times


def main():
    """
    Main function to process multiple datasets and generate graphs for each.
    """
    file_paths = [
        r'C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\factorial.txt',
        r'C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\fibonacci.txt',
        r'C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\insertionsort.txt',
        r'C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\mergesort.txt',
        r'C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\prime.txt',
        r'C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\quicksort.txt'
    ]

    max_l = 50  # Maximum value of l to test
    results = {}
    
    # Process each dataset
    for file_path in file_paths:
        dataset_name = file_path.split('\\')[-1].split('.')[0]
        accuracies, times = process_trace(file_path, max_l)
        if accuracies is not None and times is not None:
            results[dataset_name] = {
                'accuracies': accuracies,
                'times': times
            }

    # Plot accuracy for all datasets
    plt.figure(figsize=(12, 8))
    for dataset_name, data in results.items():
        plt.plot(range(1, max_l + 1), data['accuracies'], marker='o', label=f'{dataset_name} Accuracy')
    plt.title('Accuracy over Different l Values for All Datasets')
    plt.xlabel('l (History Length)')
    plt.ylabel('Accuracy (%)')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.show()

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\factorial.txt
# Total branches in trace: 31781
#
# i:1 --> (Accuracy: 89.58%, Time: 1.0067 seconds)
# i:2 --> (Accuracy: 89.57%, Time: 0.8677 seconds)
# i:3 --> (Accuracy: 89.61%, Time: 1.0256 seconds)
# i:4 --> (Accuracy: 89.61%, Time: 1.0217 seconds)
# i:5 --> (Accuracy: 89.66%, Time: 0.8784 seconds)
# i:6 --> (Accuracy: 89.67%, Time: 1.0308 seconds)
# i:7 --> (Accuracy: 89.70%, Time: 0.8493 seconds)
# i:8 --> (Accuracy: 89.74%, Time: 0.9943 seconds)
# i:9 --> (Accuracy: 89.77%, Time: 0.9955 seconds)
# i:10 --> (Accuracy: 89.61%, Time: 0.8202 seconds)
# i:11 --> (Accuracy: 89.85%, Time: 0.9898 seconds)
# i:12 --> (Accuracy: 89.81%, Time: 0.9402 seconds)
# i:13 --> (Accuracy: 89.89%, Time: 1.0949 seconds)
# i:14 --> (Accuracy: 89.86%, Time: 1.0616 seconds)
# i:15 --> (Accuracy: 89.87%, Time: 0.9744 seconds)
# i:16 --> (Accuracy: 89.96%, Time: 4.5957 seconds)
# i:17 --> (Accuracy: 89.81%, Time: 4.8782 seconds)
# i:18 --> (Accuracy: 89.83%, Time: 4.9052 seconds)
# i:19 --> (Accuracy: 89.91%, Time: 5.3301 seconds)
# i:20 --> (Accuracy: 89.92%, Time: 5.0900 seconds)
# i:21 --> (Accuracy: 89.96%, Time: 4.8592 seconds)
# i:22 --> (Accuracy: 90.43%, Time: 5.7501 seconds)
# i:23 --> (Accuracy: 90.48%, Time: 5.4387 seconds)
# i:24 --> (Accuracy: 90.50%, Time: 5.9498 seconds)
# i:25 --> (Accuracy: 90.45%, Time: 4.2450 seconds)
# i:26 --> (Accuracy: 90.35%, Time: 5.4197 seconds)
# i:27 --> (Accuracy: 90.48%, Time: 5.8164 seconds)
# i:28 --> (Accuracy: 90.52%, Time: 5.4244 seconds)
# i:29 --> (Accuracy: 90.58%, Time: 6.1202 seconds)
# i:30 --> (Accuracy: 90.63%, Time: 5.5154 seconds)
# i:31 --> (Accuracy: 90.96%, Time: 5.9093 seconds)
# i:32 --> (Accuracy: 90.90%, Time: 4.8759 seconds)
# i:33 --> (Accuracy: 91.02%, Time: 5.1254 seconds)
# i:34 --> (Accuracy: 91.11%, Time: 4.6581 seconds)
# i:35 --> (Accuracy: 91.09%, Time: 2.4862 seconds)
# i:36 --> (Accuracy: 91.15%, Time: 2.7640 seconds)
# i:37 --> (Accuracy: 91.15%, Time: 2.7724 seconds)
# i:38 --> (Accuracy: 91.17%, Time: 2.6699 seconds)
# i:39 --> (Accuracy: 91.15%, Time: 2.9216 seconds)
# i:40 --> (Accuracy: 91.11%, Time: 2.6374 seconds)
# i:41 --> (Accuracy: 91.71%, Time: 2.9528 seconds)
# i:42 --> (Accuracy: 91.69%, Time: 2.9677 seconds)
# i:43 --> (Accuracy: 91.70%, Time: 3.2181 seconds)
# i:44 --> (Accuracy: 91.70%, Time: 2.8417 seconds)
# i:45 --> (Accuracy: 91.70%, Time: 3.5664 seconds)
# i:46 --> (Accuracy: 91.72%, Time: 3.2204 seconds)
# i:47 --> (Accuracy: 91.72%, Time: 3.2673 seconds)
# i:48 --> (Accuracy: 91.72%, Time: 3.4770 seconds)
# i:49 --> (Accuracy: 91.68%, Time: 3.8243 seconds)
# i:50 --> (Accuracy: 91.69%, Time: 3.2253 seconds)
# Processing C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\fibonacci.txt
# Total branches in trace: 34163
#
# i:1 --> (Accuracy: 90.03%, Time: 2.6115 seconds)
# i:2 --> (Accuracy: 90.04%, Time: 3.2846 seconds)
# i:3 --> (Accuracy: 90.12%, Time: 2.8521 seconds)
# i:4 --> (Accuracy: 90.13%, Time: 2.6359 seconds)
# i:5 --> (Accuracy: 90.18%, Time: 3.0026 seconds)
# i:6 --> (Accuracy: 90.21%, Time: 3.9867 seconds)
# i:7 --> (Accuracy: 90.23%, Time: 4.0966 seconds)
# i:8 --> (Accuracy: 90.27%, Time: 4.0762 seconds)
# i:9 --> (Accuracy: 90.30%, Time: 3.7478 seconds)
# i:10 --> (Accuracy: 90.16%, Time: 3.4481 seconds)
# i:11 --> (Accuracy: 90.38%, Time: 4.2198 seconds)
# i:12 --> (Accuracy: 90.33%, Time: 3.9849 seconds)
# i:13 --> (Accuracy: 90.41%, Time: 4.2819 seconds)
# i:14 --> (Accuracy: 90.38%, Time: 3.9230 seconds)
# i:15 --> (Accuracy: 90.39%, Time: 4.2404 seconds)
# i:16 --> (Accuracy: 90.46%, Time: 3.7830 seconds)
# i:17 --> (Accuracy: 90.32%, Time: 3.6715 seconds)
# i:18 --> (Accuracy: 90.34%, Time: 3.8136 seconds)
# i:19 --> (Accuracy: 90.42%, Time: 3.6555 seconds)
# i:20 --> (Accuracy: 90.42%, Time: 4.6447 seconds)
# i:21 --> (Accuracy: 90.45%, Time: 3.2830 seconds)
# i:22 --> (Accuracy: 90.89%, Time: 3.8673 seconds)
# i:23 --> (Accuracy: 90.94%, Time: 3.8501 seconds)
# i:24 --> (Accuracy: 90.96%, Time: 3.7751 seconds)
# i:25 --> (Accuracy: 90.92%, Time: 3.9624 seconds)
# i:26 --> (Accuracy: 90.82%, Time: 3.1423 seconds)
# i:27 --> (Accuracy: 90.93%, Time: 4.0382 seconds)
# i:28 --> (Accuracy: 90.98%, Time: 4.2913 seconds)
# i:29 --> (Accuracy: 91.03%, Time: 3.8494 seconds)
# i:30 --> (Accuracy: 91.08%, Time: 3.9265 seconds)
# i:31 --> (Accuracy: 91.39%, Time: 3.6265 seconds)
# i:32 --> (Accuracy: 91.33%, Time: 3.3026 seconds)
# i:33 --> (Accuracy: 91.44%, Time: 4.7946 seconds)
# i:34 --> (Accuracy: 91.53%, Time: 3.7895 seconds)
# i:35 --> (Accuracy: 91.51%, Time: 3.7557 seconds)
# i:36 --> (Accuracy: 91.56%, Time: 4.1389 seconds)
# i:37 --> (Accuracy: 91.56%, Time: 3.3467 seconds)
# i:38 --> (Accuracy: 91.58%, Time: 3.8055 seconds)
# i:39 --> (Accuracy: 91.57%, Time: 3.4964 seconds)
# i:40 --> (Accuracy: 91.53%, Time: 2.7356 seconds)
# i:41 --> (Accuracy: 92.09%, Time: 2.8864 seconds)
# i:42 --> (Accuracy: 92.06%, Time: 2.9300 seconds)
# i:43 --> (Accuracy: 92.08%, Time: 0.9833 seconds)
# i:44 --> (Accuracy: 92.07%, Time: 0.8658 seconds)
# i:45 --> (Accuracy: 92.08%, Time: 0.9486 seconds)
# i:46 --> (Accuracy: 92.09%, Time: 0.8834 seconds)
# i:47 --> (Accuracy: 92.10%, Time: 0.9764 seconds)
# i:48 --> (Accuracy: 92.10%, Time: 1.0373 seconds)
# i:49 --> (Accuracy: 92.06%, Time: 0.8888 seconds)
# i:50 --> (Accuracy: 92.07%, Time: 1.0262 seconds)
# Processing C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\insertionsort.txt
# Total branches in trace: 60790
#
# i:1 --> (Accuracy: 92.98%, Time: 1.2903 seconds)
# i:2 --> (Accuracy: 93.86%, Time: 1.7015 seconds)
# i:3 --> (Accuracy: 94.14%, Time: 1.3984 seconds)
# i:4 --> (Accuracy: 94.16%, Time: 1.2668 seconds)
# i:5 --> (Accuracy: 94.21%, Time: 2.9271 seconds)
# i:6 --> (Accuracy: 94.23%, Time: 5.4409 seconds)
# i:7 --> (Accuracy: 94.24%, Time: 5.1340 seconds)
# i:8 --> (Accuracy: 94.26%, Time: 4.6029 seconds)
# i:9 --> (Accuracy: 94.27%, Time: 5.0946 seconds)
# i:10 --> (Accuracy: 94.19%, Time: 5.7103 seconds)
# i:11 --> (Accuracy: 94.31%, Time: 4.1014 seconds)
# i:12 --> (Accuracy: 94.29%, Time: 4.3913 seconds)
# i:13 --> (Accuracy: 94.33%, Time: 4.0167 seconds)
# i:14 --> (Accuracy: 94.32%, Time: 4.4503 seconds)
# i:15 --> (Accuracy: 94.31%, Time: 3.9137 seconds)
# i:16 --> (Accuracy: 94.36%, Time: 5.3245 seconds)
# i:17 --> (Accuracy: 94.27%, Time: 5.4638 seconds)
# i:18 --> (Accuracy: 94.28%, Time: 5.1174 seconds)
# i:19 --> (Accuracy: 94.31%, Time: 6.2118 seconds)
# i:20 --> (Accuracy: 94.32%, Time: 6.0612 seconds)
# i:21 --> (Accuracy: 94.35%, Time: 5.9260 seconds)
# i:22 --> (Accuracy: 94.59%, Time: 5.6142 seconds)
# i:23 --> (Accuracy: 94.61%, Time: 5.9092 seconds)
# i:24 --> (Accuracy: 94.62%, Time: 4.1355 seconds)
# i:25 --> (Accuracy: 94.59%, Time: 3.5289 seconds)
# i:26 --> (Accuracy: 94.54%, Time: 1.3703 seconds)
# i:27 --> (Accuracy: 94.59%, Time: 1.3297 seconds)
# i:28 --> (Accuracy: 94.62%, Time: 1.4036 seconds)
# i:29 --> (Accuracy: 94.65%, Time: 1.2988 seconds)
# i:30 --> (Accuracy: 94.68%, Time: 1.4135 seconds)
# i:31 --> (Accuracy: 94.85%, Time: 1.5019 seconds)
# i:32 --> (Accuracy: 94.82%, Time: 1.3490 seconds)
# i:33 --> (Accuracy: 94.89%, Time: 1.4860 seconds)
# i:34 --> (Accuracy: 94.92%, Time: 3.3843 seconds)
# i:35 --> (Accuracy: 94.91%, Time: 5.1024 seconds)
# i:36 --> (Accuracy: 94.94%, Time: 1.4244 seconds)
# i:37 --> (Accuracy: 94.94%, Time: 1.3655 seconds)
# i:38 --> (Accuracy: 94.95%, Time: 1.4870 seconds)
# i:39 --> (Accuracy: 94.94%, Time: 1.4669 seconds)
# i:40 --> (Accuracy: 94.93%, Time: 1.4476 seconds)
# i:41 --> (Accuracy: 95.24%, Time: 1.4671 seconds)
# i:42 --> (Accuracy: 95.23%, Time: 1.4317 seconds)
# i:43 --> (Accuracy: 95.24%, Time: 1.5213 seconds)
# i:44 --> (Accuracy: 95.23%, Time: 1.5460 seconds)
# i:45 --> (Accuracy: 95.23%, Time: 1.5863 seconds)
# i:46 --> (Accuracy: 95.25%, Time: 1.5443 seconds)
# i:47 --> (Accuracy: 95.25%, Time: 1.4228 seconds)
# i:48 --> (Accuracy: 95.25%, Time: 1.5444 seconds)
# i:49 --> (Accuracy: 95.23%, Time: 1.5061 seconds)
# i:50 --> (Accuracy: 95.23%, Time: 1.5613 seconds)
# Processing C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\mergesort.txt
# Total branches in trace: 60292
#
# i:1 --> (Accuracy: 91.79%, Time: 1.3494 seconds)
# i:2 --> (Accuracy: 92.77%, Time: 1.3318 seconds)
# i:3 --> (Accuracy: 93.09%, Time: 1.3180 seconds)
# i:4 --> (Accuracy: 93.12%, Time: 1.1984 seconds)
# i:5 --> (Accuracy: 93.19%, Time: 1.2836 seconds)
# i:6 --> (Accuracy: 93.18%, Time: 1.1963 seconds)
# i:7 --> (Accuracy: 93.22%, Time: 1.3208 seconds)
# i:8 --> (Accuracy: 93.23%, Time: 1.3293 seconds)
# i:9 --> (Accuracy: 93.29%, Time: 1.2324 seconds)
# i:10 --> (Accuracy: 93.20%, Time: 1.3025 seconds)
# i:11 --> (Accuracy: 93.32%, Time: 1.2602 seconds)
# i:12 --> (Accuracy: 93.29%, Time: 1.3203 seconds)
# i:13 --> (Accuracy: 93.34%, Time: 1.2687 seconds)
# i:14 --> (Accuracy: 93.34%, Time: 1.3810 seconds)
# i:15 --> (Accuracy: 93.31%, Time: 1.3380 seconds)
# i:16 --> (Accuracy: 93.36%, Time: 1.3015 seconds)
# i:17 --> (Accuracy: 93.25%, Time: 1.3762 seconds)
# i:18 --> (Accuracy: 93.27%, Time: 1.2504 seconds)
# i:19 --> (Accuracy: 93.29%, Time: 1.3337 seconds)
# i:20 --> (Accuracy: 93.29%, Time: 1.3852 seconds)
# i:21 --> (Accuracy: 93.33%, Time: 1.2991 seconds)
# i:22 --> (Accuracy: 93.60%, Time: 1.3502 seconds)
# i:23 --> (Accuracy: 93.61%, Time: 1.2741 seconds)
# i:24 --> (Accuracy: 93.60%, Time: 1.3782 seconds)
# i:25 --> (Accuracy: 93.59%, Time: 1.2674 seconds)
# i:26 --> (Accuracy: 93.54%, Time: 1.3804 seconds)
# i:27 --> (Accuracy: 93.61%, Time: 1.3868 seconds)
# i:28 --> (Accuracy: 93.62%, Time: 1.2829 seconds)
# i:29 --> (Accuracy: 93.66%, Time: 1.3977 seconds)
# i:30 --> (Accuracy: 93.68%, Time: 1.3135 seconds)
# i:31 --> (Accuracy: 93.86%, Time: 1.3990 seconds)
# i:32 --> (Accuracy: 93.82%, Time: 1.3172 seconds)
# i:33 --> (Accuracy: 93.88%, Time: 1.3887 seconds)
# i:34 --> (Accuracy: 93.92%, Time: 1.3954 seconds)
# i:35 --> (Accuracy: 93.91%, Time: 1.3152 seconds)
# i:36 --> (Accuracy: 93.96%, Time: 1.3838 seconds)
# i:37 --> (Accuracy: 93.95%, Time: 1.3158 seconds)
# i:38 --> (Accuracy: 93.94%, Time: 1.4503 seconds)
# i:39 --> (Accuracy: 93.94%, Time: 1.4260 seconds)
# i:40 --> (Accuracy: 93.92%, Time: 1.3267 seconds)
# i:41 --> (Accuracy: 94.22%, Time: 1.4412 seconds)
# i:42 --> (Accuracy: 94.22%, Time: 1.3370 seconds)
# i:43 --> (Accuracy: 94.22%, Time: 1.3972 seconds)
# i:44 --> (Accuracy: 94.21%, Time: 1.3049 seconds)
# i:45 --> (Accuracy: 94.24%, Time: 1.4532 seconds)
# i:46 --> (Accuracy: 94.23%, Time: 1.4465 seconds)
# i:47 --> (Accuracy: 94.25%, Time: 1.3507 seconds)
# i:48 --> (Accuracy: 94.26%, Time: 1.4516 seconds)
# i:49 --> (Accuracy: 94.24%, Time: 1.3866 seconds)
# i:50 --> (Accuracy: 94.23%, Time: 1.4614 seconds)
# Processing C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\prime.txt
# Total branches in trace: 31705
#
# i:1 --> (Accuracy: 89.59%, Time: 0.7834 seconds)
# i:2 --> (Accuracy: 89.57%, Time: 0.7222 seconds)
# i:3 --> (Accuracy: 89.60%, Time: 0.7776 seconds)
# i:4 --> (Accuracy: 89.60%, Time: 0.8015 seconds)
# i:5 --> (Accuracy: 89.66%, Time: 0.7449 seconds)
# i:6 --> (Accuracy: 89.66%, Time: 0.8023 seconds)
# i:7 --> (Accuracy: 89.70%, Time: 0.8020 seconds)
# i:8 --> (Accuracy: 89.74%, Time: 0.7327 seconds)
# i:9 --> (Accuracy: 89.76%, Time: 0.8190 seconds)
# i:10 --> (Accuracy: 89.61%, Time: 0.7426 seconds)
# i:11 --> (Accuracy: 89.85%, Time: 0.8205 seconds)
# i:12 --> (Accuracy: 89.80%, Time: 0.7171 seconds)
# i:13 --> (Accuracy: 89.89%, Time: 0.8372 seconds)
# i:14 --> (Accuracy: 89.85%, Time: 0.8288 seconds)
# i:15 --> (Accuracy: 89.87%, Time: 0.7511 seconds)
# i:16 --> (Accuracy: 89.95%, Time: 0.8335 seconds)
# i:17 --> (Accuracy: 89.80%, Time: 0.8633 seconds)
# i:18 --> (Accuracy: 89.82%, Time: 0.7502 seconds)
# i:19 --> (Accuracy: 89.91%, Time: 0.8334 seconds)
# i:20 --> (Accuracy: 89.92%, Time: 0.8660 seconds)
# i:21 --> (Accuracy: 89.95%, Time: 0.7663 seconds)
# i:22 --> (Accuracy: 90.43%, Time: 0.8334 seconds)
# i:23 --> (Accuracy: 90.47%, Time: 0.7507 seconds)
# i:24 --> (Accuracy: 90.49%, Time: 0.8492 seconds)
# i:25 --> (Accuracy: 90.45%, Time: 0.8503 seconds)
# i:26 --> (Accuracy: 90.34%, Time: 0.7661 seconds)
# i:27 --> (Accuracy: 90.47%, Time: 0.8346 seconds)
# i:28 --> (Accuracy: 90.52%, Time: 0.7673 seconds)
# i:29 --> (Accuracy: 90.58%, Time: 0.8786 seconds)
# i:30 --> (Accuracy: 90.63%, Time: 0.7877 seconds)
# i:31 --> (Accuracy: 90.96%, Time: 0.8490 seconds)
# i:32 --> (Accuracy: 90.90%, Time: 0.8831 seconds)
# i:33 --> (Accuracy: 91.02%, Time: 0.8011 seconds)
# i:34 --> (Accuracy: 91.11%, Time: 0.8834 seconds)
# i:35 --> (Accuracy: 91.09%, Time: 0.8874 seconds)
# i:36 --> (Accuracy: 91.14%, Time: 0.7783 seconds)
# i:37 --> (Accuracy: 91.14%, Time: 0.8882 seconds)
# i:38 --> (Accuracy: 91.17%, Time: 0.8198 seconds)
# i:39 --> (Accuracy: 91.15%, Time: 0.8927 seconds)
# i:40 --> (Accuracy: 91.11%, Time: 0.9166 seconds)
# i:41 --> (Accuracy: 91.71%, Time: 0.8131 seconds)
# i:42 --> (Accuracy: 91.69%, Time: 0.8694 seconds)
# i:43 --> (Accuracy: 91.70%, Time: 0.7993 seconds)
# i:44 --> (Accuracy: 91.70%, Time: 0.8835 seconds)
# i:45 --> (Accuracy: 91.70%, Time: 0.8827 seconds)
# i:46 --> (Accuracy: 91.71%, Time: 0.8175 seconds)
# i:47 --> (Accuracy: 91.72%, Time: 0.8831 seconds)
# i:48 --> (Accuracy: 91.72%, Time: 0.9171 seconds)
# i:49 --> (Accuracy: 91.68%, Time: 0.8164 seconds)
# i:50 --> (Accuracy: 91.69%, Time: 0.9333 seconds)
# Processing C:\Users\prato\OneDrive\Desktop\EECE7205 - Fundamentals of CompE\Project\Trace files\quicksort.txt
# Total branches in trace: 57460
#
# i:1 --> (Accuracy: 92.16%, Time: 1.2154 seconds)
# i:2 --> (Accuracy: 93.15%, Time: 1.1327 seconds)
# i:3 --> (Accuracy: 93.45%, Time: 1.2992 seconds)
# i:4 --> (Accuracy: 93.47%, Time: 1.1837 seconds)
# i:5 --> (Accuracy: 93.50%, Time: 1.1336 seconds)
# i:6 --> (Accuracy: 93.51%, Time: 1.2168 seconds)
# i:7 --> (Accuracy: 93.53%, Time: 1.1347 seconds)
# i:8 --> (Accuracy: 93.56%, Time: 1.2149 seconds)
# i:9 --> (Accuracy: 93.57%, Time: 1.1679 seconds)
# i:10 --> (Accuracy: 93.48%, Time: 1.2300 seconds)
# i:11 --> (Accuracy: 93.60%, Time: 1.2492 seconds)
# i:12 --> (Accuracy: 93.60%, Time: 1.1501 seconds)
# i:13 --> (Accuracy: 93.63%, Time: 1.2664 seconds)
# i:14 --> (Accuracy: 93.64%, Time: 1.3074 seconds)
# i:15 --> (Accuracy: 93.64%, Time: 1.2259 seconds)
# i:16 --> (Accuracy: 93.69%, Time: 1.3241 seconds)
# i:17 --> (Accuracy: 93.56%, Time: 1.2255 seconds)
# i:18 --> (Accuracy: 93.58%, Time: 2.7515 seconds)
# i:19 --> (Accuracy: 93.62%, Time: 4.2502 seconds)
# i:20 --> (Accuracy: 93.63%, Time: 6.0783 seconds)
# i:21 --> (Accuracy: 93.65%, Time: 6.3024 seconds)
# i:22 --> (Accuracy: 93.91%, Time: 6.1298 seconds)
# i:23 --> (Accuracy: 93.93%, Time: 6.1796 seconds)
# i:24 --> (Accuracy: 93.94%, Time: 4.8766 seconds)
# i:25 --> (Accuracy: 93.90%, Time: 5.2172 seconds)
# i:26 --> (Accuracy: 93.86%, Time: 7.1461 seconds)
# i:27 --> (Accuracy: 93.93%, Time: 5.0553 seconds)
# i:28 --> (Accuracy: 93.94%, Time: 3.2818 seconds)
# i:29 --> (Accuracy: 93.98%, Time: 1.2599 seconds)
# i:30 --> (Accuracy: 93.99%, Time: 1.3148 seconds)
# i:31 --> (Accuracy: 94.19%, Time: 1.2331 seconds)
# i:32 --> (Accuracy: 94.16%, Time: 1.3689 seconds)
# i:33 --> (Accuracy: 94.22%, Time: 1.3457 seconds)
# i:34 --> (Accuracy: 94.26%, Time: 1.2522 seconds)
# i:35 --> (Accuracy: 94.26%, Time: 1.3701 seconds)
# i:36 --> (Accuracy: 94.28%, Time: 1.2826 seconds)
# i:37 --> (Accuracy: 94.27%, Time: 1.3684 seconds)
# i:38 --> (Accuracy: 94.30%, Time: 1.3835 seconds)
# i:39 --> (Accuracy: 94.29%, Time: 1.2823 seconds)
# i:40 --> (Accuracy: 94.28%, Time: 1.3978 seconds)
# i:41 --> (Accuracy: 94.61%, Time: 1.2862 seconds)
# i:42 --> (Accuracy: 94.58%, Time: 1.3478 seconds)
# i:43 --> (Accuracy: 94.60%, Time: 1.4173 seconds)
# i:44 --> (Accuracy: 94.59%, Time: 1.2827 seconds)
# i:45 --> (Accuracy: 94.58%, Time: 1.3716 seconds)
# i:46 --> (Accuracy: 94.59%, Time: 1.2816 seconds)
# i:47 --> (Accuracy: 94.60%, Time: 1.3627 seconds)
# i:48 --> (Accuracy: 94.60%, Time: 1.3004 seconds)
# i:49 --> (Accuracy: 94.58%, Time: 1.3665 seconds)
# i:50 --> (Accuracy: 94.58%, Time: 1.4164 seconds)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
